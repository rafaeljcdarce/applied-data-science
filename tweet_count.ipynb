# %%
import pandas as pd
import matplotlib.pyplot as plt
import tikzplotlib

# %%
df = pd.read_csv('/Users/rileyevans/Downloads/results-20210502-192759.csv')
df = df.rename(columns={'f0_': 'count'})
df = df.set_index('d')

# %%
df.head()
# Out:
#             count
# d
# 2020-11-02   5323
# 2020-11-03   5609
# 2020-11-04   3954
# 2020-11-05   5155
# 2020-11-06   4671

# %%
df.plot(legend=False)
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Number of tweets collected')
tikzplotlib.save('historic-tweets-count.tex')
