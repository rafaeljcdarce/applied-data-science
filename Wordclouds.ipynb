# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200 # 200 e.g. is really fine, but slower

# %%
df = pd.read_csv('/Users/rileyevans/Downloads/recent.csv')
df
# Out:
#                            t  sents    c
# 0                     Pfizer     -1  122
# 1              GetVaccinated     -1   93
# 2                    Moderna     -1   80
# 3                          1     -1   66
# 4               VaccinesWork     -1   59
# ...                      ...    ...  ...
# 17897               THANKYOU      1    1
# 17898    COVIDVACCINEVICTIMS      1    1
# 17899          ShawnVidiella      1    1
# 17900  AngeliaGipsonDesselle      1    1
# 17901         KristiSimmonds      1    1
#
# [17902 rows x 3 columns]

# %%
pos_df = df[df['sents'] == 1][['t', 'c']]

# %%
neg_df = df[df['sents'] == -1][['t', 'c']]

# %%
mask = np.array(Image.open('/Users/rileyevans/Downloads/452-4528141_solid-color-map-of-usa-hd-png-download.png.png'))

# %%
def plot(text):
    wc = WordCloud(background_color="white", max_words=1000, mask=mask)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.savefig('recent-hashtag-neg-wordcloud.png')
    plt.show()

# %%
plot(neg_df.set_index('t').to_dict()['c'])

# %%
plot(pos_df.set_index('t').to_dict()['c'])
